# %% [markdown]
# # Main Dashboard of PhD experiments in pre silicon AI/DB workloads int/fp

# %%
# %matplotlib inline
results_file = 'presilicon_results.csv'
import os
#from pca.analytics import *
from pca.pca import *
from pre_silicon.presi_data_gen import *
from clustering.distortion import *
from clustering.clustering import *
from clustering.cluster_score import *

# %% [markdown]
# # Characterization of worklaods based on instructions kind

# %%
files = dir_list = os.listdir("tests/pre_silicon_runs_ml_db")
my_labels = ['int', 'fp', 'branch', 'store', 'load','io', 'other']
df_global = pd.DataFrame(columns=my_labels)
for file_name in files:
    test_name = file_name.strip("csv").strip(".")
    df = read_histogram(os.path.join("tests/pre_silicon_runs_ml_db",file_name))
    df_sumary,_ = calculate_values_int_fp(df)
    df_global.loc[test_name] = df_sumary['probability'].values.tolist()

display(df_global)
plot_stacked_bar(df_global)

df_global.reset_index(inplace=True)
df_global = df_global.rename(columns={"index": "test_name"} )

df_global.to_csv("presilicon_results_spec.csv")
# Out:
#                                     int        fp    branch     store  \
# redis_memtier_4cpu             0.147283  0.001007  0.300828  0.386302
# resnet50_int8                  0.247326  0.072138  0.187661  0.249629
# resnet50_fp32                  0.249282  0.087660  0.180546  0.244436
# redis_memtier_12cpu            0.132315  0.000793  0.311147  0.411453
# redis_memtier_16cpu            0.129210  0.000750  0.313106  0.417137
# redis_memtier_2cpu_gated       0.180121  0.001105  0.283461  0.336874
# redis_memtier_8cpu             0.137227  0.000874  0.307462  0.402751
# benchdnn_bf16                  0.179221  0.025984  0.228715  0.306713
# resnet101_throughput_avx_fp32  0.151530  0.236702  0.147215  0.184079
# resnet101_throughput_amx_fp32  0.151143  0.233724  0.149985  0.186267
# redis_2                        0.153104  0.001086  0.301278  0.370442
# resnet101_throughput_amx_int8  0.204227  0.087096  0.216569  0.263915
# resnet101_throughput_avx_int8  0.201956  0.085086  0.216800  0.266720
# benchdnn_conv_avx2             0.082721  0.401514  0.126733  0.161064
#
#                                    load        io     other
# redis_memtier_4cpu             0.029231  0.000114  0.135236
# resnet50_int8                  0.023363  0.000118  0.219766
# resnet50_fp32                  0.022004  0.000118  0.215954
# redis_memtier_12cpu            0.023082  0.000128  0.121081
# redis_memtier_16cpu            0.021712  0.000129  0.117957
# redis_memtier_2cpu_gated       0.035094  0.000100  0.163246
# redis_memtier_8cpu             0.025026  0.000123  0.126537
# benchdnn_bf16                  0.029471  0.000117  0.229779
# resnet101_throughput_avx_fp32  0.018616  0.000078  0.261779
# resnet101_throughput_amx_fp32  0.018901  0.000077  0.259904
# redis_2                        0.032602  0.000120  0.141367
# resnet101_throughput_amx_int8  0.027390  0.000100  0.200703
# resnet101_throughput_avx_int8  0.027321  0.000101  0.202016
# benchdnn_conv_avx2             0.016958  0.000060  0.210950

# %% [markdown]
# ## PCA

# %%
df = df_global

df_ = df.loc[:, df.columns != 'test_name']
df_ = (df_-df_.min())/(df_.max()-df_.min())
extracted_col = df["test_name"]
df_.insert(0, 'test_name', extracted_col)
df_.set_index('test_name')
df_.to_csv('normalized_speccpu_df.csv')
df = df_

features = list(df.columns)[1:]
test_column = list(df.columns)[0]

pca_df = get_PCA(df,features)

# %% [markdown]
# ## Explained Variance

# %%
from pca.pca import *
x = get_features(df_global,features)
X_std = StandardScaler().fit_transform(x)
exp_var_pca = get_explained_variance(X_std)
plot_explained_variance(exp_var_pca)

# %% [markdown]
# ## Display PCA

# %%
filename = 'post_silicon/summary_phd.csv'
df2 = pd.read_csv(filename)
df2.fillna(0,inplace=True)

merged_df = pca_df.merge(df2[['test_name', 'Kind']], on='test_name', how='left')

merged_df.loc[merged_df['test_name'].str.contains('redis', case=False, na=False), 'Kind'] = 1
merged_df.loc[merged_df['test_name'].str.contains('resnet', case=False, na=False), 'Kind'] = 0
merged_df.loc[merged_df['test_name'].str.contains('benchdnn', case=False, na=False), 'Kind'] = 0


display(merged_df)

ax1 = merged_df.plot.scatter(x='principal component 1',y='principal component 2',c='Kind', colormap='viridis')
for i, label in enumerate(merged_df['test_name']):
    plt.annotate(i, (merged_df['principal component 1'][i], merged_df['principal component 2'][i]))

pca_df=merged_df
# Out:
#     principal component 1  principal component 2  \
# 0               -2.040322               0.570694
# 1                0.616136              -1.940513
# 2                0.793622              -1.871398
# 3               -2.259594               1.218901
# 4               -2.259430               1.382009
# 5               -1.518701              -0.542824
# 6               -2.172525               1.002895
# 7               -0.361811              -0.993405
# 8                3.279683               0.257487
# 9                3.228053               0.277645
# 10              -2.242421               0.139792
# 11               0.379814              -0.945164
# 12               0.344277              -0.921525
# 13               4.213220               2.365405
#
#                         test_name  Kind
# 0              redis_memtier_4cpu   1.0
# 1                   resnet50_int8   0.0
# 2                   resnet50_fp32   0.0
# 3             redis_memtier_12cpu   1.0
# 4             redis_memtier_16cpu   1.0
# 5        redis_memtier_2cpu_gated   1.0
# 6              redis_memtier_8cpu   1.0
# 7                   benchdnn_bf16   0.0
# 8   resnet101_throughput_avx_fp32   0.0
# 9   resnet101_throughput_amx_fp32   0.0
# 10                        redis_2   1.0
# 11  resnet101_throughput_amx_int8   0.0
# 12  resnet101_throughput_avx_int8   0.0
# 13             benchdnn_conv_avx2   0.0

# %%
from pca.pca import *
plot_pca_vectors(X_std, features)

# %%
from clustering.clustering import *
df_result,kmeans,SSE = kmean_cluster(pca_df,2)
display(df_result)
plot_kmeans(pca_df, kmeans)
# Out:
#    PRED                      test_name
# 0     0  resnet101_throughput_avx_fp32
# 0     0  resnet101_throughput_amx_fp32
# 0     0             benchdnn_conv_avx2
# 1     1             redis_memtier_4cpu
# 1     1                  resnet50_int8
# 1     1                  resnet50_fp32
# 1     1            redis_memtier_12cpu
# 1     1            redis_memtier_16cpu
# 1     1       redis_memtier_2cpu_gated
# 1     1             redis_memtier_8cpu
# 1     1                  benchdnn_bf16
# 1     1                        redis_2
# 1     1  resnet101_throughput_amx_int8
# 1     1  resnet101_throughput_avx_int8

# %% [markdown]
# # Get the test cases closer to centroid

# %%
from sklearn.metrics import pairwise_distances_argmin_min
X = pd.read_csv("pca.csv", usecols = ['principal component 1','principal component 2'])
closest, _ = pairwise_distances_argmin_min(kmeans.cluster_centers_, X)
pca_df_ = pd.read_csv("pca.csv")
df = pca_df_.iloc[closest]
df
# Out:
#    Unnamed: 0  principal component 1  principal component 2  \
# 8           8               3.279683               0.257487
# 5           5              -1.518701              -0.542824
#
#                        test_name
# 8  resnet101_throughput_avx_fp32
# 5       redis_memtier_2cpu_gated

# %%
list_tests = df['test_name'].tolist()
df2 = df_global[df_global['test_name'].isin(list_tests)]
df2.plot.barh(x="test_name")
df2
# Out:
#                        test_name       int        fp    branch     store  \
# 5       redis_memtier_2cpu_gated  0.180121  0.001105  0.283461  0.336874
# 8  resnet101_throughput_avx_fp32  0.151530  0.236702  0.147215  0.184079
#
#        load        io     other
# 5  0.035094  0.000100  0.163246
# 8  0.018616  0.000078  0.261779

# %% [markdown]
# ### Automatic label of clusters based cosine similarity to FP/INT

# %% [markdown]
# \begin{equation}
# \cos ({\bf t},{\bf e})= {{\bf t} {\bf e} \over \|{\bf t}\| \|{\bf e}\|} = \frac{ \sum_{i=1}^{n}{{\bf t}_i{\bf e}_i} }{ \sqrt{\sum_{i=1}^{n}{({\bf t}_i)^2}} \sqrt{\sum_{i=1}^{n}{({\bf e}_i)^2}} }
# \end{equation}

# %%
display(pca_df)
df_sorted = pca_df.sort_values(by='Kind')
fp_tests = df_sorted[df_sorted['Kind'] == 0]
int_tests = df_sorted[df_sorted['Kind'] == 1]

df = df_result
#display(df)
df_sorted = df.sort_values(by='PRED')
A = df_sorted[df_sorted['PRED'] == 0]
B = df_sorted[df_sorted['PRED'] == 1]


C = normalize(A,B,fp_tests,int_tests)
C_sorted =  C.sort_values(by='test_name', ascending=False)

REAL = pca_df
REAL_sorted = REAL.sort_values(by='test_name', ascending=False)

labels_pred = C_sorted["PRED"].tolist()
labels_pred_ = [eval(i) for i in labels_pred]
labels_pred = labels_pred_

labels_true = REAL_sorted["Kind"].tolist()

df = pd.DataFrame({'labels':C_sorted['test_name'], 'val_pred':labels_pred, 'val_true':labels_true})
display(df)
df.to_csv("clusters.csv")

df_ = df.loc[~(df['val_pred'] == df['val_true'])]
display(df_)

ax = df.plot.barh(x='labels', y=['val_pred','val_true'],  rot=0, title= "Cluster 0: FP / 1: INT")

scores_result = scores(labels_true,labels_pred)

df = pd.DataFrame({'scores':['adjusted_rand_score', 'normalized_mutual_info_score', 'fowlkes_mallows_score'], 'val':scores_result[:-1]})
ax = df.plot.barh(x='scores', y='val', rot=0, title= "Scores (HIB)")
# Out:
#     principal component 1  principal component 2  \
# 0               -2.040322               0.570694
# 1                0.616136              -1.940513
# 2                0.793622              -1.871398
# 3               -2.259594               1.218901
# 4               -2.259430               1.382009
# 5               -1.518701              -0.542824
# 6               -2.172525               1.002895
# 7               -0.361811              -0.993405
# 8                3.279683               0.257487
# 9                3.228053               0.277645
# 10              -2.242421               0.139792
# 11               0.379814              -0.945164
# 12               0.344277              -0.921525
# 13               4.213220               2.365405
#
#                         test_name  Kind
# 0              redis_memtier_4cpu   1.0
# 1                   resnet50_int8   0.0
# 2                   resnet50_fp32   0.0
# 3             redis_memtier_12cpu   1.0
# 4             redis_memtier_16cpu   1.0
# 5        redis_memtier_2cpu_gated   1.0
# 6              redis_memtier_8cpu   1.0
# 7                   benchdnn_bf16   0.0
# 8   resnet101_throughput_avx_fp32   0.0
# 9   resnet101_throughput_amx_fp32   0.0
# 10                        redis_2   1.0
# 11  resnet101_throughput_amx_int8   0.0
# 12  resnet101_throughput_avx_int8   0.0
# 13             benchdnn_conv_avx2   0.0
# A = PRED -> 0
# cosine_similarity vs fp_tests 0.6123724356957945
# cosine_similarity vs int_tests 0.0
# cosine_similarity_fp > cosine_similarity_int
# Assigining 0 label to pred cluster
#
# B = PRED -> 1
# cosine_similarity vs fp_tests 0.5330017908890261
# cosine_similarity vs int_tests 0.7385489458759965
# cosine_similarity_int > cosine_similarity_fp
# Assigining 1 label to pred cluster
#                           labels  val_pred  val_true
# 1                  resnet50_int8         1       0.0
# 1                  resnet50_fp32         1       0.0
# 1  resnet101_throughput_avx_int8         1       0.0
# 0  resnet101_throughput_avx_fp32         0       0.0
# 1  resnet101_throughput_amx_int8         1       0.0
# 0  resnet101_throughput_amx_fp32         0       0.0
# 1             redis_memtier_8cpu         1       1.0
# 1             redis_memtier_4cpu         1       1.0
# 1       redis_memtier_2cpu_gated         1       1.0
# 1            redis_memtier_16cpu         1       1.0
# 1            redis_memtier_12cpu         1       1.0
# 1                        redis_2         1       1.0
# 0             benchdnn_conv_avx2         0       0.0
# 1                  benchdnn_bf16         1       0.0
#                           labels  val_pred  val_true
# 1                  resnet50_int8         1       0.0
# 1                  resnet50_fp32         1       0.0
# 1  resnet101_throughput_avx_int8         1       0.0
# 1  resnet101_throughput_amx_int8         1       0.0
# 1                  benchdnn_bf16         1       0.0
# adjusted_rand_score 0.02569593147751606
#
# normalized_mutual_info_score 0.23541808259515326
#
# fowlkes_mallows_score 0.5606732120242913
#
# hamming_distance 0.35714285714285715

# %%
import matplotlib.pyplot as plt
import numpy
from sklearn import metrics

df = pd.read_csv('clusters.csv')
display(df)
actual = df['val_true'].tolist()
predicted = df['val_pred'].tolist()

confusion_matrix = metrics.confusion_matrix(actual, predicted)

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = ['ML', 'DB'])

cm_display.plot()
plt.show()
# Out:
#     Unnamed: 0                         labels  val_pred  val_true
# 0            1                  resnet50_int8         1       0.0
# 1            1                  resnet50_fp32         1       0.0
# 2            1  resnet101_throughput_avx_int8         1       0.0
# 3            0  resnet101_throughput_avx_fp32         0       0.0
# 4            1  resnet101_throughput_amx_int8         1       0.0
# 5            0  resnet101_throughput_amx_fp32         0       0.0
# 6            1             redis_memtier_8cpu         1       1.0
# 7            1             redis_memtier_4cpu         1       1.0
# 8            1       redis_memtier_2cpu_gated         1       1.0
# 9            1            redis_memtier_16cpu         1       1.0
# 10           1            redis_memtier_12cpu         1       1.0
# 11           1                        redis_2         1       1.0
# 12           0             benchdnn_conv_avx2         0       0.0
# 13           1                  benchdnn_bf16         1       0.0

# %% [markdown]
# ## Get best number of clusters based on variance

# %%
from clustering.distortion import *
from clustering.cluster_score import *
#clusters = calculate_elbow(pca_df)[0]
x1 = pca_df["principal component 1"].values
x2 = pca_df["principal component 2"].values
X = np.array(list(zip(x1, x2))).reshape(len(x1), 2)
clusters,distortions,inertias = find_optimal_clusters(X, max_clusters=10)
display(f"Optimal number of clusters = {clusters}")

x = range(1, len(distortions)+1)
kn = KneeLocator(x, distortions, curve='convex', direction='decreasing')
kn.plot_knee()
# Out:
# 'Optimal number of clusters = 1'

# %%
plot_elbow(range(1,11),distortions,inertias)

# %% [markdown]
# ## Clasification based on N number of clusters

# %%
from clustering.clustering import *
df_result,kmeans,SSE = kmean_cluster(pca_df,3)
display(df_result)
plot_kmeans(pca_df, kmeans)
# Out:
#    PRED                      test_name
# 0     0  resnet101_throughput_avx_fp32
# 0     0  resnet101_throughput_amx_fp32
# 0     0             benchdnn_conv_avx2
# 1     1                  resnet50_int8
# 1     1                  resnet50_fp32
# 1     1                  benchdnn_bf16
# 1     1  resnet101_throughput_amx_int8
# 1     1  resnet101_throughput_avx_int8
# 2     2             redis_memtier_4cpu
# 2     2            redis_memtier_12cpu
# 2     2            redis_memtier_16cpu
# 2     2       redis_memtier_2cpu_gated
# 2     2             redis_memtier_8cpu
# 2     2                        redis_2

# %%
SSE_vector = []
for x in range(1,10):
    df_result_,kmeans,SSE = kmean_cluster(pca_df,x)
    SSE_vector.append(SSE)
print(SSE_vector)

# Plot SSE vs. number of clusters
plt.plot(range(1,10), SSE_vector, marker='o')
plt.title('SSE vs. Number of Clusters')
plt.xlabel('Number of Clusters')
plt.ylabel('Sum of Squared Errors (SSE)')
plt.grid(True)
plt.show()
# Out:
# [87.53649656396631, 35.20534340092418, 8.504867219797292, 4.957344054904988, 2.7682429189493485, 1.2698933790011997, 0.5629367276156341, 0.21122050546571058, 0.09796042027556734]

# %%
pca_df_ = pd.read_csv("pca.csv")
display(pca_df)
df_sorted = pca_df.sort_values(by='Kind')
fp_tests = df_sorted[df_sorted['Kind'] == 0]
int_tests = df_sorted[df_sorted['Kind'] == 1]

df = df_result
display(df)
df_sorted = df.sort_values(by='PRED')
A = df_sorted[df_sorted['PRED'] == 0]
B = df_sorted[df_sorted['PRED'] == 1]

# option 1
# convert 2 -> 1
B_ = df_sorted[df_sorted['PRED'] == 2]
B_['PRED'] = 1

C = normalize(A,B,fp_tests,int_tests)
C_sorted =  C.sort_values(by='test_name', ascending=False)

D = normalize(A,B_,fp_tests,int_tests)
D_sorted =  D.sort_values(by='test_name', ascending=False)

complete = pd.concat([C_sorted, D_sorted], ignore_index=True).drop_duplicates()
complete = complete.sort_values(by='test_name', ascending=False)
display(complete)

REAL = pca_df
REAL_sorted = REAL.sort_values(by='test_name', ascending=False)

labels_pred = complete["PRED"].tolist()
labels_pred_ = [eval(i) for i in labels_pred]
labels_pred = labels_pred_

labels_true = REAL_sorted["Kind"].tolist()



df = pd.DataFrame({'labels':complete['test_name'], 'val_pred':labels_pred, 'val_true':labels_true})
display(df)
df.to_csv("clusters.csv")

df_ = df.loc[~(df['val_pred'] == df['val_true'])]
display(df_)

ax = df.plot.barh(x='labels', y=['val_pred','val_true'],  rot=0, title= "Cluster 0: FP / 1: INT")

scores_result = scores(labels_true,labels_pred)

df = pd.DataFrame({'scores':['adjusted_rand_score', 'normalized_mutual_info_score', 'fowlkes_mallows_score'], 'val':scores_result[:-1]})
ax = df.plot.barh(x='scores', y='val', rot=0, title= "Scores (HIB)")
# Out:
#     principal component 1  principal component 2  \
# 0               -2.040322               0.570694
# 1                0.616136              -1.940513
# 2                0.793622              -1.871398
# 3               -2.259594               1.218901
# 4               -2.259430               1.382009
# 5               -1.518701              -0.542824
# 6               -2.172525               1.002895
# 7               -0.361811              -0.993405
# 8                3.279683               0.257487
# 9                3.228053               0.277645
# 10              -2.242421               0.139792
# 11               0.379814              -0.945164
# 12               0.344277              -0.921525
# 13               4.213220               2.365405
#
#                         test_name  Kind
# 0              redis_memtier_4cpu   1.0
# 1                   resnet50_int8   0.0
# 2                   resnet50_fp32   0.0
# 3             redis_memtier_12cpu   1.0
# 4             redis_memtier_16cpu   1.0
# 5        redis_memtier_2cpu_gated   1.0
# 6              redis_memtier_8cpu   1.0
# 7                   benchdnn_bf16   0.0
# 8   resnet101_throughput_avx_fp32   0.0
# 9   resnet101_throughput_amx_fp32   0.0
# 10                        redis_2   1.0
# 11  resnet101_throughput_amx_int8   0.0
# 12  resnet101_throughput_avx_int8   0.0
# 13             benchdnn_conv_avx2   0.0
#    PRED                      test_name
# 0     0  resnet101_throughput_avx_fp32
# 0     0  resnet101_throughput_amx_fp32
# 0     0             benchdnn_conv_avx2
# 1     1                  resnet50_int8
# 1     1                  resnet50_fp32
# 1     1                  benchdnn_bf16
# 1     1  resnet101_throughput_amx_int8
# 1     1  resnet101_throughput_avx_int8
# 2     2             redis_memtier_4cpu
# 2     2            redis_memtier_12cpu
# 2     2            redis_memtier_16cpu
# 2     2       redis_memtier_2cpu_gated
# 2     2             redis_memtier_8cpu
# 2     2                        redis_2
# A = PRED -> 0
# cosine_similarity vs fp_tests 0.6123724356957945
# cosine_similarity vs int_tests 0.0
# cosine_similarity_fp > cosine_similarity_int
# Assigining 0 label to pred cluster
#
# B = PRED -> 1
# cosine_similarity vs fp_tests 0.7905694150420948
# cosine_similarity vs int_tests 0.0
# cosine_similarity_fp > cosine_similarity_int
# Assigining 0 label to pred cluster
#
# A = PRED -> 0
# cosine_similarity vs fp_tests 0.6123724356957945
# cosine_similarity vs int_tests 0.0
# cosine_similarity_fp > cosine_similarity_int
# Assigining 0 label to pred cluster
#
# B = PRED -> 1
# cosine_similarity vs fp_tests 0.0
# cosine_similarity vs int_tests 1.0000000000000002
# cosine_similarity_int > cosine_similarity_fp
# Assigining 1 label to pred cluster
# /var/folders/cq/r380vqnd7fd_v5hhy522gw140000gn/T/ipykernel_9101/921413153.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   B_['PRED'] = 1
#    PRED                      test_name
# 0     0                  resnet50_int8
# 1     0                  resnet50_fp32
# 2     0  resnet101_throughput_avx_int8
# 3     0  resnet101_throughput_avx_fp32
# 4     0  resnet101_throughput_amx_int8
# 5     0  resnet101_throughput_amx_fp32
# 10    1             redis_memtier_8cpu
# 11    1             redis_memtier_4cpu
# 12    1       redis_memtier_2cpu_gated
# 13    1            redis_memtier_16cpu
# 14    1            redis_memtier_12cpu
# 15    1                        redis_2
# 6     0             benchdnn_conv_avx2
# 7     0                  benchdnn_bf16
#                            labels  val_pred  val_true
# 0                   resnet50_int8         0       0.0
# 1                   resnet50_fp32         0       0.0
# 2   resnet101_throughput_avx_int8         0       0.0
# 3   resnet101_throughput_avx_fp32         0       0.0
# 4   resnet101_throughput_amx_int8         0       0.0
# 5   resnet101_throughput_amx_fp32         0       0.0
# 10             redis_memtier_8cpu         1       1.0
# 11             redis_memtier_4cpu         1       1.0
# 12       redis_memtier_2cpu_gated         1       1.0
# 13            redis_memtier_16cpu         1       1.0
# 14            redis_memtier_12cpu         1       1.0
# 15                        redis_2         1       1.0
# 6              benchdnn_conv_avx2         0       0.0
# 7                   benchdnn_bf16         0       0.0
# Empty DataFrame
# Columns: [labels, val_pred, val_true]
# Index: []
# adjusted_rand_score 1.0
#
# normalized_mutual_info_score 1.0
#
# fowlkes_mallows_score 1.0
#
# hamming_distance 0.0

# %% [markdown]
# ## Hiearchial clustering

# %%
from scipy.cluster import hierarchy
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

# Generate sample data
#X, _ = make_blobs(n_samples=300, centers=4, cluster_std=0.60, random_state=0)
X = pca_df[['principal component 1', 'principal component 2']].copy()

# Perform hierarchical clustering to obtain the linkage matrix
Z = hierarchy.linkage(X, method='ward')

# Plot the dendrogram
plt.figure(figsize=(10, 5))
dn = hierarchy.dendrogram(Z,labels=pca_df['test_name'].values)

# Rotate the labels vertically
plt.xticks(rotation=90)

plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Sample Index')
plt.ylabel('Distance')
plt.show()

# %% [markdown]
# ## Get optimal set of of clusters based on simulation time vs SSE

# %%
list_workloads = pca_df['test_name'].values
# Generate random simulation time values between 1 and 20
simulation_times = np.random.randint(1, 21, size=len(pca_df))

# Add the new column to the DataFrame
pca_df['simulation_time'] = simulation_times
pca_df.to_csv("pca_df_sim_time.csv")

# %%
pca_df = pd.read_csv("pca_df_sim_time_fixed_time.csv")

# %%
def find_min_simulation_time(df, workloads):
    # Filter the DataFrame based on the provided set of workloads
    filtered_df = df[df['test_name'].isin(workloads)]
    
    # Find the row with the minimum simulation time
    min_row = filtered_df.loc[filtered_df['simulation_time'].idxmin()]
    
    # Extract the workload name and minimum simulation time
    min_workload = min_row['test_name']
    min_time = min_row['simulation_time']
    
    return min_workload, min_time

total_clusters_time_v = []
for x in range(1,10):
    df_result_,kmeans,SSE = kmean_cluster(pca_df,x)
    workloads_per_cluster = {}
    total_clusters_time = 0
    for cluster, group in df_result_.groupby('PRED'):
        workloads = set(group['test_name'].unique())
        min_workload, min_time = find_min_simulation_time(pca_df, workloads)
        print(f"Workload with minimum simulation time: {min_workload}, Time: {min_time}")
        total_clusters_time += min_time
    print(f"Cluster size = {x} Sim time = {total_clusters_time}")
    total_clusters_time_v.append(total_clusters_time)
    
print(total_clusters_time_v)
# Out:
# Workload with minimum simulation time: redis_memtier_8cpu, Time: 9
# Cluster size = 1 Sim time = 9
# Workload with minimum simulation time: redis_memtier_8cpu, Time: 9
# Workload with minimum simulation time: resnet101_throughput_amx_fp32, Time: 32
# Cluster size = 2 Sim time = 41
# Workload with minimum simulation time: resnet101_throughput_amx_int8, Time: 61
# Workload with minimum simulation time: resnet101_throughput_amx_fp32, Time: 32
# Workload with minimum simulation time: redis_memtier_8cpu, Time: 9
# Cluster size = 3 Sim time = 102
# Workload with minimum simulation time: resnet101_throughput_amx_int8, Time: 61
# Workload with minimum simulation time: redis_memtier_8cpu, Time: 9
# Workload with minimum simulation time: resnet101_throughput_amx_fp32, Time: 32
# Workload with minimum simulation time: benchdnn_conv_avx2, Time: 69
# Cluster size = 4 Sim time = 171
# Workload with minimum simulation time: benchdnn_bf16, Time: 69
# Workload with minimum simulation time: benchdnn_conv_avx2, Time: 69
# Workload with minimum simulation time: resnet101_throughput_amx_int8, Time: 61
# Workload with minimum simulation time: redis_memtier_8cpu, Time: 9
# Workload with minimum simulation time: resnet101_throughput_amx_fp32, Time: 32
# Cluster size = 5 Sim time = 240
# Workload with minimum simulation time: benchdnn_conv_avx2, Time: 69
# Workload with minimum simulation time: redis_memtier_2cpu_gated, Time: 112
# Workload with minimum simulation time: resnet50_int8, Time: 169
# Workload with minimum simulation time: redis_memtier_8cpu, Time: 9
# Workload with minimum simulation time: resnet101_throughput_amx_fp32, Time: 32
# Workload with minimum simulation time: resnet101_throughput_amx_int8, Time: 61
# Cluster size = 6 Sim time = 452
# Workload with minimum simulation time: resnet101_throughput_amx_int8, Time: 61
# Workload with minimum simulation time: redis_memtier_8cpu, Time: 9
# Workload with minimum simulation time: resnet101_throughput_amx_fp32, Time: 32
# Workload with minimum simulation time: redis_memtier_4cpu, Time: 77
# Workload with minimum simulation time: benchdnn_conv_avx2, Time: 69
# Workload with minimum simulation time: resnet50_int8, Time: 169
# Workload with minimum simulation time: redis_memtier_2cpu_gated, Time: 112
# Cluster size = 7 Sim time = 529
# Workload with minimum simulation time: redis_memtier_2cpu_gated, Time: 112
# Workload with minimum simulation time: resnet101_throughput_amx_fp32, Time: 32
# Workload with minimum simulation time: resnet101_throughput_amx_int8, Time: 61
# Workload with minimum simulation time: redis_memtier_8cpu, Time: 9
# Workload with minimum simulation time: benchdnn_conv_avx2, Time: 69
# Workload with minimum simulation time: resnet50_int8, Time: 169
# Workload with minimum simulation time: redis_memtier_4cpu, Time: 77
# Workload with minimum simulation time: benchdnn_bf16, Time: 69
# Cluster size = 8 Sim time = 598
# Workload with minimum simulation time: resnet50_int8, Time: 169
# Workload with minimum simulation time: redis_memtier_8cpu, Time: 9
# Workload with minimum simulation time: resnet101_throughput_amx_fp32, Time: 32
# Workload with minimum simulation time: benchdnn_conv_avx2, Time: 69
# Workload with minimum simulation time: benchdnn_bf16, Time: 69
# Workload with minimum simulation time: resnet101_throughput_amx_int8, Time: 61
# Workload with minimum simulation time: redis_memtier_2cpu_gated, Time: 112
# Workload with minimum simulation time: redis_2, Time: 126
# Workload with minimum simulation time: redis_memtier_4cpu, Time: 77
# Cluster size = 9 Sim time = 724
# [9, 41, 102, 171, 240, 452, 529, 598, 724]

# %%
plt.plot(range(1, 10), SSE_vector, marker='o', label='SSE')
plt.plot(range(1, 10), total_clusters_time_v, marker='x', label='Simulation Time')
plt.title('SSE vs. Number of Clusters')
plt.xlabel('Number of Clusters')
plt.ylabel('Values')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Min-max normalization for total_clusters_time_v
min_total_clusters_time_v = min(total_clusters_time_v)
max_total_clusters_time_v = max(total_clusters_time_v)
normalized_total_clusters_time_v = [(x - min_total_clusters_time_v) / (max_total_clusters_time_v - min_total_clusters_time_v) for x in total_clusters_time_v]

# Min-max normalization for SSE_vector
min_SSE_vector = min(SSE_vector)
max_SSE_vector = max(SSE_vector)
normalized_SSE_vector = [(x - min_SSE_vector) / (max_SSE_vector - min_SSE_vector) for x in SSE_vector]

plt.plot(range(1, 10), normalized_SSE_vector, marker='o', label='SSE')
plt.plot(range(1, 10), normalized_total_clusters_time_v, marker='x', label='Simulation Time')
plt.title('SSE vs. Number of Clusters')
plt.xlabel('Number of Clusters')
plt.ylabel('Values')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Decision Tree Algorithm

# %%
display(pca_df)
# Use known kind based on KMEANS prediction
X = pca_df[["principal component 1","principal component 2"]]
y = pca_df[["Kind"]]

accuracy_results = {}
# Out:
#     Unnamed: 0  principal component 1  principal component 2  \
# 0            0              -2.026623               0.597176
# 1            1               0.720825              -2.018397
# 2            2               0.924069              -1.910955
# 3            3              -2.232027               1.296451
# 4            4              -2.227643               1.471389
# 5            5              -1.520603              -0.622840
# 6            6              -2.150937               1.062229
# 7            7              -0.488707              -1.152886
# 8            8               3.192015               0.281263
# 9            9               3.141067               0.300766
# 10          10              -2.246377               0.131268
# 11          11               0.412608              -1.015197
# 12          12               0.370976              -0.989666
# 13          13               4.131356               2.569399
#
#                         test_name  Kind  simulation_time
# 0              redis_memtier_4cpu     1               77
# 1                   resnet50_int8     0              169
# 2                   resnet50_fp32     0              201
# 3             redis_memtier_12cpu     1               11
# 4             redis_memtier_16cpu     1               13
# 5        redis_memtier_2cpu_gated     1              112
# 6              redis_memtier_8cpu     1                9
# 7                   benchdnn_bf16     0               69
# 8   resnet101_throughput_avx_fp32     0               65
# 9   resnet101_throughput_amx_fp32     0               32
# 10                        redis_2     1              126
# 11  resnet101_throughput_amx_int8     0               61
# 12  resnet101_throughput_avx_int8     0               63
# 13             benchdnn_conv_avx2     0               69

# %%
from statistics import mean
from statistics import stdev
def get_accuracty(X,y,loops,clf):
    p_total = []
    r_total = []
    f_total = []

    for i in range(loops):

        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)
        clf.fit(X_train,y_train)

        # Predict Accuracy Score
        y_pred = clf.predict(X_test)
        p,r,f,s = precision_recall_fscore_support(y_test, y_pred, average='weighted', labels=y_pred,zero_division=1)
        p_total.append(p)
        r_total.append(r)
        f_total.append(f)
    return p_total,r_total,f_total


from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import precision_recall_fscore_support

# Split into training and test set
# import warnings filter
from warnings import simplefilter
# ignore all future warnings
simplefilter(action='ignore', category=FutureWarning)

from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

loops = 10
clf = DecisionTreeClassifier()
p_total_wpca,r_total_wpca,f_total_wpca = get_accuracty(X,y,loops,clf)
    
print(f"Precision score {mean(p_total_wpca)} STED {stdev(p_total_wpca)}")
print(f"Recall score {mean(r_total_wpca)} STED {stdev(p_total_wpca)}")
print(f"F-beta score {mean(f_total_wpca)} STED {stdev(p_total_wpca)}")

accuracy_results['Decision_Tree_precision_score_wpca'] = mean(p_total_wpca)
accuracy_results['Decision_Tree_recall_score_wpca'] = mean(r_total_wpca)
accuracy_results['Decision_Tree_F_score_wpca'] = mean(f_total_wpca)
# Out:
# Precision score 1.0 STED 0.0
# Recall score 1.0 STED 0.0
# F-beta score 1.0 STED 0.0

# %% [markdown]
# ### Decision Tree Algorithm w/o PCA

# %%
from statistics import mean
from statistics import stdev

from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import precision_recall_fscore_support
from warnings import simplefilter
simplefilter(action='ignore', category=FutureWarning)

from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

loops = 10
clf = DecisionTreeClassifier()

filename = 'normalized_speccpu_df.csv'
df_data = pd.read_csv(filename)
df_data.fillna(0,inplace=True)

if os.path.exists(filename):
    df = pd.read_csv(filename)
    filename = 'post_silicon/summary_phd.csv'
    df2 = pd.read_csv(filename)
    df2.fillna(0,inplace=True)

    merged_df = df_data.merge(df2[['test_name', 'Kind']], on='test_name', how='left')
    merged_df.loc[merged_df['test_name'].str.contains('redis', case=False, na=False), 'Kind'] = 1
    merged_df.loc[merged_df['test_name'].str.contains('resnet', case=False, na=False), 'Kind'] = 0
    merged_df.loc[merged_df['test_name'].str.contains('benchdnn', case=False, na=False), 'Kind'] = 0

    features = list(df.columns)[2:]
    display(merged_df)
    test_column = list(merged_df.columns)[0]
    x = merged_df.loc[:, features].values
    X_std = StandardScaler().fit_transform(x)
    y = merged_df['Kind']

p_total,r_total,f_total = get_accuracty(x,y,loops,clf)
    
print(f"Precision score {mean(p_total)} STED {stdev(p_total)}")
print(f"Recall score {mean(r_total)} STED {stdev(p_total)}")
print(f"F-beta score {mean(f_total)} STED {stdev(p_total)}")

accuracy_results['Decision_Tree_precision_score'] = mean(p_total)
accuracy_results['Decision_Tree_recall_score'] = mean(r_total)
accuracy_results['Decision_Tree_F_score'] = mean(f_total)
# Out:
#     Unnamed: 0                      test_name       int        fp    branch  \
# 0            0             redis_memtier_4cpu  0.387616  0.000642  0.934121
# 1            1                  resnet50_int8  0.988256  0.178129  0.326916
# 2            2                  resnet50_fp32  1.000000  0.216861  0.288742
# 3            3            redis_memtier_12cpu  0.297750  0.000109  0.989492
# 4            4            redis_memtier_16cpu  0.279108  0.000000  1.000000
# 5            5       redis_memtier_2cpu_gated  0.584768  0.000886  0.840939
# 6            6             redis_memtier_8cpu  0.327241  0.000309  0.969717
# 7            7                  benchdnn_bf16  0.579368  0.062965  0.547193
# 8            8  resnet101_throughput_avx_fp32  0.413115  0.588755  0.109902
# 9            9  resnet101_throughput_amx_fp32  0.410789  0.581324  0.124761
# 10          10                        redis_2  0.422563  0.000840  0.936539
# 11          11  resnet101_throughput_amx_int8  0.729499  0.215455  0.482022
# 12          12  resnet101_throughput_avx_int8  0.715861  0.210439  0.483265
# 13          13             benchdnn_conv_avx2  0.000000  1.000000  0.000000
#
#        store      load        io     other  Kind
# 0   0.879585  0.676694  0.786505  0.120138   1.0
# 1   0.345858  0.353143  0.846799  0.707880   0.0
# 2   0.325579  0.278214  0.850127  0.681372   0.0
# 3   0.977802  0.337691  0.989432  0.021723   1.0
# 4   1.000000  0.262130  1.000000  0.000000   1.0
# 5   0.686561  1.000000  0.579001  0.314894   1.0
# 6   0.943821  0.444863  0.923003  0.059658   1.0
# 7   0.568781  0.689951  0.826299  0.777503   0.0
# 8   0.089878  0.091440  0.263329  1.000000   0.0
# 9   0.098422  0.107148  0.247475  0.986959   0.0
# 10  0.817650  0.862616  0.881262  0.162766   1.0
# 11  0.401647  0.575222  0.581955  0.575334   0.0
# 12  0.412602  0.571390  0.602252  0.584460   0.0
# 13  0.000000  0.000000  0.000000  0.646583   0.0
# Precision score 1.0 STED 0.0
# Recall score 1.0 STED 0.0
# F-beta score 1.0 STED 0.0

# %%
import matplotlib.pyplot as plt
import pandas as pd
from statistics import mean
from statistics import stdev

# Sample data for dataframe 1
data1 = {'Category': ['Precision Score', 'F Score'],
         '2D': [mean(p_total_wpca), mean(f_total_wpca)]}
df1 = pd.DataFrame(data1)

# Sample data for dataframe 2
data2 = {'Category': ['Precision Score', 'F Socre'],
         '7D': [mean(p_total), mean(f_total)]}
df2 = pd.DataFrame(data2)

# Create the figure and subplot
fig, ax = plt.subplots()

# Plotting bars for dataframe 1
width = 0.35
x = range(len(df1['Category']))
ax.bar(x, df1['2D'], width, label='2D')

# Plotting bars for dataframe 2 next to the bars from dataframe 1
ax.bar([i + width for i in x], df2['7D'], width, label='7D')

# Customize the plot
ax.set_xticks([i + width/2 for i in x])
ax.set_xticklabels(df1['Category'])
ax.set_xlabel('Categories')
ax.set_ylabel('% Accuracy ')
ax.set_title('Decision Tree performance with multiple dimensions (HIB)')
ax.legend()

# Show the plot
plt.show()

# %%
accuracy_results_df = pd.DataFrame(list(accuracy_results.items()),columns=['algorithm','accuracy'])
display(accuracy_results_df)
#ccuracy_results_df = accuracy_results_df.drop([0,2])
#isplay(accuracy_results_df)
accuracy_results_df.plot.barh(x='algorithm', title = 'Performance of SML');
# Out:
#                             algorithm  accuracy
# 0  Decision_Tree_precision_score_wpca       1.0
# 1     Decision_Tree_recall_score_wpca       1.0
# 2          Decision_Tree_F_score_wpca       1.0
# 3       Decision_Tree_precision_score       1.0
# 4          Decision_Tree_recall_score       1.0
# 5               Decision_Tree_F_score       1.0

# %% [markdown]
# ## Calculate Probaily

# %%
all_data = []

def calculate_probabilities(df):
    sorted_df = df.sort_values(by='count', ascending=False)
    top_counts = sorted_df.head(10)['count']
    total_count = top_counts.sum()
    probabilities = top_counts / total_count
    result = dict(zip(sorted_df.head(10)['mnemonic'], probabilities))
    return result

files = dir_list = os.listdir("tests/pre_silicon_runs_ml_db")
for file_name in files:
    test_name = file_name.strip("csv").strip(".")
    df = read_histogram(os.path.join("tests/pre_silicon_runs_ml_db",file_name))
    probabilities = calculate_probabilities(df)
    # Extract the top 10 instructions and their probabilities
    top_instructions = list(probabilities.keys())[:10]
    prob_values = list(probabilities.values())[:10]
        
    # Append data to the list
    data_row = {'Test_Name': test_name}
    for i, prob_value in enumerate(prob_values, start=1):
        data_row[str(i)] = prob_value
    all_data.append(data_row)

# Create DataFrame from the collected data
df = pd.DataFrame(all_data)
display(df)

import matplotlib.pyplot as plt

# Plotting
plt.figure(figsize=(10, 6))

# Iterate over each row (test) in the DataFrame
for index, row in df.iterrows():
    # Skip the 'Test_Name' column
    values = row.iloc[1:].astype(float)  # Start from index 1 to skip the 'Test_Name' column
    plt.plot(range(1, 11), values.values, label=index)

# Add labels and legend
plt.title('Top 10 Instructions Probabilities for Each Test')
plt.xlabel('Instruction')
plt.ylabel('Probability')
plt.xticks(range(1, 11))
plt.legend(title='Test Name', labels=df['Test_Name'].values)  # Use the 'Test_Name' column for legend labels
plt.tight_layout()
plt.show()
# Out:
#                         Test_Name         1         2         3         4  \
# 0              redis_memtier_4cpu  0.434581  0.101923  0.078169  0.064043
# 1                   resnet50_int8  0.332209  0.128036  0.103382  0.103160
# 2                   resnet50_fp32  0.316884  0.128720  0.125993  0.104695
# 3             redis_memtier_12cpu  0.412276  0.088195  0.086749  0.082469
# 4             redis_memtier_16cpu  0.406258  0.088389  0.086461  0.086206
# 5        redis_memtier_2cpu_gated  0.447493  0.122877  0.081972  0.063522
# 6              redis_memtier_8cpu  0.420612  0.092990  0.084053  0.076195
# 7                   benchdnn_bf16  0.455569  0.113878  0.095203  0.055409
# 8   resnet101_throughput_avx_fp32  0.326542  0.222015  0.115918  0.071794
# 9   resnet101_throughput_amx_fp32  0.323582  0.225371  0.114867  0.071800
# 10                        redis_2  0.444019  0.111985  0.074301  0.064742
# 11  resnet101_throughput_amx_int8  0.360248  0.124449  0.105599  0.099268
# 12  resnet101_throughput_avx_int8  0.365617  0.121769  0.104903  0.099819
# 13             benchdnn_conv_avx2  0.497435  0.179769  0.100615  0.060632
#
#            5         6         7         8         9        10
# 0   0.062889  0.062707  0.059428  0.051018  0.042787  0.042455
# 1   0.081375  0.073200  0.051962  0.044895  0.041098  0.040684
# 2   0.075711  0.075120  0.051699  0.042824  0.041539  0.036815
# 3   0.082224  0.069521  0.055978  0.049803  0.036810  0.035975
# 4   0.084697  0.070479  0.056930  0.047634  0.036622  0.036326
# 5   0.056045  0.055972  0.053249  0.042730  0.040984  0.035156
# 6   0.075964  0.067872  0.054505  0.053294  0.038871  0.035644
# 7   0.053424  0.051453  0.048968  0.046348  0.041815  0.037934
# 8   0.060415  0.050047  0.046414  0.044347  0.031604  0.030904
# 9   0.061560  0.049941  0.045993  0.043946  0.031628  0.031312
# 10  0.062242  0.050646  0.050494  0.049887  0.048062  0.043623
# 11  0.077860  0.050553  0.048970  0.046821  0.043128  0.043104
# 12  0.076905  0.050594  0.047923  0.046846  0.043135  0.042489
# 13  0.046890  0.032708  0.022424  0.021154  0.019783  0.018590

# %% [markdown]
# ## Calculate entropy

# %%
def calculate_probabilities(df):
    sorted_df = df.sort_values(by='count', ascending=False)
    top_counts = sorted_df['count']
    total_count = top_counts.sum()
    probabilities = top_counts / total_count
    result = dict(zip(sorted_df['mnemonic'], probabilities))
    return result

def calculate_entropy(df):
    entropy_total = 0
    # Initialize an empty list to store entropy values
    prob = calculate_probabilities(df)
    for instruction, prob_value in prob.items():
        if prob_value > 0.0:
            entropy = prob_value * np.log2(prob_value)
            entropy_total+=entropy
    return -(entropy_total)

# Initialize lists to store test names and entropy values
test_names = []
entropy_values = []

files = dir_list = os.listdir("tests/pre_silicon_runs_ml_db")
for file_name in files:
    test_name = file_name.strip("csv").strip(".")
    df = read_histogram(os.path.join("tests/pre_silicon_runs_ml_db",file_name))
    entropy = calculate_entropy(df)
    # Append test name and entropy value to lists
    test_names.append(test_name)
    entropy_values.append(entropy)

# Create DataFrame
df_entropy = pd.DataFrame({'Test_Name': test_names, 'Entropy': entropy_values})

print(df_entropy)
# Plotting
plt.figure(figsize=(10, 6))
plt.barh(df_entropy['Test_Name'], df_entropy['Entropy'], color='skyblue')
plt.title('Entropy for Each Test')
plt.xlabel('Entropy')
plt.ylabel('Test Name')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
#                         Test_Name   Entropy
# 0              redis_memtier_4cpu  4.423212
# 1                   resnet50_int8  4.799526
# 2                   resnet50_fp32  4.725774
# 3             redis_memtier_12cpu  4.340233
# 4             redis_memtier_16cpu  4.314753
# 5        redis_memtier_2cpu_gated  4.492507
# 6              redis_memtier_8cpu  4.375839
# 7                   benchdnn_bf16  4.800080
# 8   resnet101_throughput_avx_fp32  4.379258
# 9   resnet101_throughput_amx_fp32  4.389028
# 10                        redis_2  4.440583
# 11  resnet101_throughput_amx_int8  4.801655
# 12  resnet101_throughput_avx_int8  4.801866
# 13             benchdnn_conv_avx2  3.680694

# %%
def find_min_simulation_time(df, workloads):
    # Filter the DataFrame based on the provided set of workloads
    filtered_df = df[df['test_name'].isin(workloads)]
    
    # Find the row with the minimum simulation time
    min_row = filtered_df.loc[filtered_df['simulation_time'].idxmin()]
    
    # Extract the workload name and minimum simulation time
    min_workload = min_row['test_name']
    min_time = min_row['simulation_time']
    
    return min_workload, min_time

total_clusters_time_v = []
mean_entropy_list = []
for x in range(1,10):
    df_result_,kmeans,SSE = kmean_cluster(pca_df,x)
    workloads_per_cluster = {}
    total_clusters_time = 0
    total_entropy = 0
    for cluster, group in df_result_.groupby('PRED'):
        workloads = set(group['test_name'].unique())
        min_workload, min_time = find_min_simulation_time(pca_df, workloads)
        entropy = df_entropy[df_entropy['Test_Name'] == min_workload]['Entropy'].iloc[0]
        total_entropy += entropy
        print(f"Workload with minimum simulation time: {min_workload}, Time: {min_time}, Entropy: {entropy} ")
        mean_entropy = total_entropy/x
        total_clusters_time += min_time
    mean_entropy_list.append(mean_entropy)
    print(f"Cluster size = {x} Sim time = {total_clusters_time} Mean Entropy = {mean_entropy}")
    total_clusters_time_v.append(total_clusters_time)

    
# Plot the list
# Define x-values starting from 1
x_values = range(1, len(mean_entropy_list) + 1)
# Plot the list with custom x-values
plt.plot(x_values, mean_entropy_list)
plt.xlabel('Clusters')
plt.ylabel('Mean Entropy')
plt.title('Mean Entropy over multiple clusters of best sim time vs SSE')
plt.show()
# Out:
# Workload with minimum simulation time: redis_memtier_8cpu, Time: 9, Entropy: 4.375838858176186
# Cluster size = 1 Sim time = 9 Mean Entropy = 4.375838858176186
# Workload with minimum simulation time: redis_memtier_8cpu, Time: 9, Entropy: 4.375838858176186
# Workload with minimum simulation time: resnet101_throughput_amx_fp32, Time: 32, Entropy: 4.389027759452521
# Cluster size = 2 Sim time = 41 Mean Entropy = 4.3824333088143534
# Workload with minimum simulation time: redis_memtier_8cpu, Time: 9, Entropy: 4.375838858176186
# Workload with minimum simulation time: resnet101_throughput_amx_int8, Time: 61, Entropy: 4.801655171775304
# Workload with minimum simulation time: resnet101_throughput_amx_fp32, Time: 32, Entropy: 4.389027759452521
# Cluster size = 3 Sim time = 102 Mean Entropy = 4.522173929801337
# Workload with minimum simulation time: resnet101_throughput_amx_int8, Time: 61, Entropy: 4.801655171775304
# Workload with minimum simulation time: redis_memtier_8cpu, Time: 9, Entropy: 4.375838858176186
# Workload with minimum simulation time: resnet101_throughput_amx_fp32, Time: 32, Entropy: 4.389027759452521
# Workload with minimum simulation time: benchdnn_conv_avx2, Time: 69, Entropy: 3.680693888999068
# Cluster size = 4 Sim time = 171 Mean Entropy = 4.31180391960077
# Workload with minimum simulation time: resnet101_throughput_amx_int8, Time: 61, Entropy: 4.801655171775304
# Workload with minimum simulation time: redis_memtier_8cpu, Time: 9, Entropy: 4.375838858176186
# Workload with minimum simulation time: resnet101_throughput_amx_fp32, Time: 32, Entropy: 4.389027759452521
# Workload with minimum simulation time: benchdnn_bf16, Time: 69, Entropy: 4.800079802195338
# Workload with minimum simulation time: benchdnn_conv_avx2, Time: 69, Entropy: 3.680693888999068
# Cluster size = 5 Sim time = 240 Mean Entropy = 4.409459096119683
# Workload with minimum simulation time: redis_memtier_8cpu, Time: 9, Entropy: 4.375838858176186
# Workload with minimum simulation time: resnet101_throughput_amx_int8, Time: 61, Entropy: 4.801655171775304
# Workload with minimum simulation time: benchdnn_conv_avx2, Time: 69, Entropy: 3.680693888999068
# Workload with minimum simulation time: redis_memtier_2cpu_gated, Time: 112, Entropy: 4.492507015725612
# Workload with minimum simulation time: resnet101_throughput_amx_fp32, Time: 32, Entropy: 4.389027759452521
# Workload with minimum simulation time: resnet50_int8, Time: 169, Entropy: 4.799525893215198
# Cluster size = 6 Sim time = 452 Mean Entropy = 4.423208097890648
# Workload with minimum simulation time: resnet101_throughput_amx_int8, Time: 61, Entropy: 4.801655171775304
# Workload with minimum simulation time: redis_memtier_8cpu, Time: 9, Entropy: 4.375838858176186
# Workload with minimum simulation time: resnet101_throughput_amx_fp32, Time: 32, Entropy: 4.389027759452521
# Workload with minimum simulation time: benchdnn_conv_avx2, Time: 69, Entropy: 3.680693888999068
# Workload with minimum simulation time: redis_memtier_4cpu, Time: 77, Entropy: 4.423212119497582
# Workload with minimum simulation time: resnet50_int8, Time: 169, Entropy: 4.799525893215198
# Workload with minimum simulation time: redis_memtier_2cpu_gated, Time: 112, Entropy: 4.492507015725612
# Cluster size = 7 Sim time = 529 Mean Entropy = 4.4232086724059245
# Workload with minimum simulation time: resnet101_throughput_amx_fp32, Time: 32, Entropy: 4.389027759452521
# Workload with minimum simulation time: benchdnn_bf16, Time: 69, Entropy: 4.800079802195338
# Workload with minimum simulation time: redis_memtier_8cpu, Time: 9, Entropy: 4.375838858176186
# Workload with minimum simulation time: benchdnn_conv_avx2, Time: 69, Entropy: 3.680693888999068
# Workload with minimum simulation time: resnet50_int8, Time: 169, Entropy: 4.799525893215198
# Workload with minimum simulation time: resnet101_throughput_amx_int8, Time: 61, Entropy: 4.801655171775304
# Workload with minimum simulation time: redis_memtier_2cpu_gated, Time: 112, Entropy: 4.492507015725612
# Workload with minimum simulation time: redis_memtier_4cpu, Time: 77, Entropy: 4.423212119497582
# Cluster size = 8 Sim time = 598 Mean Entropy = 4.470317563629601
# Workload with minimum simulation time: resnet50_int8, Time: 169, Entropy: 4.799525893215198
# Workload with minimum simulation time: redis_memtier_8cpu, Time: 9, Entropy: 4.375838858176186
# Workload with minimum simulation time: resnet101_throughput_amx_fp32, Time: 32, Entropy: 4.389027759452521
# Workload with minimum simulation time: benchdnn_conv_avx2, Time: 69, Entropy: 3.680693888999068
# Workload with minimum simulation time: redis_memtier_2cpu_gated, Time: 112, Entropy: 4.492507015725612
# Workload with minimum simulation time: resnet101_throughput_amx_int8, Time: 61, Entropy: 4.801655171775304
# Workload with minimum simulation time: redis_2, Time: 126, Entropy: 4.4405833418743486
# Workload with minimum simulation time: benchdnn_bf16, Time: 69, Entropy: 4.800079802195338
# Workload with minimum simulation time: redis_memtier_4cpu, Time: 77, Entropy: 4.423212119497582
# Cluster size = 9 Sim time = 724 Mean Entropy = 4.4670137612123515

# %% [markdown]
# # Back up
